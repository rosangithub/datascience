# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset/iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'])
plt.xlabel('Sepal Length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
df.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 108  109            6.7           2.5            5.8           1.8
# 77    78            6.7           3.0            5.0           1.7
# 66    67            5.6           3.0            4.5           1.5
# 48    49            5.3           3.7            1.5           0.2
# 38    39            4.4           3.0            1.3           0.2
#
#              Species
# 108   Iris-virginica
# 77   Iris-versicolor
# 66   Iris-versicolor
# 48       Iris-setosa
# 38       Iris-setosa

# %%
df['Species']= df['Species'].replace({'Iris-setosa':0,'Iris-versicolor':2,'Iris-virginica':3})
# Out:
# /tmp/ipykernel_28681/731382084.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Species']= df['Species'].replace({'Iris-setosa':0,'Iris-versicolor':2,'Iris-virginica':3})

# %%
plt.style.use('fivethirtyeight')

# %%
df.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 133  134            6.3           2.8            5.1           1.5        3
# 53    54            5.5           2.3            4.0           1.3        2
# 73    74            6.1           2.8            4.7           1.2        2
# 131  132            7.9           3.8            6.4           2.0        3
# 100  101            6.3           3.3            6.0           2.5        3

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'],c=df['Species'],cmap="winter",alpha=0.8)
plt.xlabel('sepal length')
plt.ylabel('petal lenth')
plt.colorbar()
# cmp means color map

# %%
plt.figure(figsize=(9,5))
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'],c=df['Species'],cmap="jet",alpha=0.8)
plt.xlabel('sepal length')
plt.ylabel('petal lenth')
plt.colorbar()

# %%
batters=pd.read_csv('dataset/batter.csv')

# %%
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
batters.shape
# Out:
# (605, 4)

# %%
df=batters.sample(25)

# %%
df
# Out:
#               batter  runs        avg  strike_rate
# 334         OF Smith    51  17.000000   102.000000
# 456          I Udana    15   5.000000   136.363636
# 121          R Parag   522  16.838710   120.276498
# 501     Ravi Bishnoi     8   4.000000    44.444444
# 118        RS Bopara   531  29.500000   113.461538
# 213         UT Yadav   177   9.833333   100.568182
# 402      A Choudhary    25  25.000000   125.000000
# 109        CH Morris   618  22.071429   149.636804
# 153        KV Sharma   317  15.095238   111.228070
# 419     DE Bollinger    21  21.000000    91.304348
# 18      F du Plessis  3403  34.373737   127.167414
# 473  Karanveer Singh    12  12.000000    70.588235
# 489       SM Harwood     9        NaN    64.285714
# 259         M Kartik   113  16.142857   103.669725
# 249        MM Sharma   122   8.133333   101.666667
# 103         TL Suman   676  21.125000   115.161840
# 474        AA Chavan    12   6.000000   109.090909
# ...

# %%
# use fo annotation
plt.figure(figsize=(18,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
for i in range(df.shape[0]):
    plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])

# %%
plt.figure(figsize=(18,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
for i in range(df.shape[0]):
    plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])
plt.axhline(100,color='red')
plt.axvline(25,color='blue')
plt.axhline(140,color='black')

# %%
x=[1,2,3,4]
y=[5,6,7,8]
plt.scatter(x,y)
plt.text(1,5,'point 1')
plt.text(2,6,'point 2')
plt.text(3,7,'point 3')
plt.text(4,8,'point 4')
# Out:
# Text(4, 8, 'point 4')

# %% [markdown]
# ## Subplots
